# %%
# !ls
# Out:
# latest.txt  main.py  __pycache__  sample_data

# %%
import xkcd

# %% [markdown]
# ### Updating the latest comic for quick load time 🚀
#   It is not necessary to use this function as it will automatically update the latest comic as soon as you run the `get_comic()` function.
#   Only difference here being that you need to specify for verbose whether it is `True` for `Flase`
#
#   The latest comic is stored in the `latest.txt` file

# %%
comic = xkcd.get_latest_comic(verbose=True)
# Out:
#     current comic =====> 2781
#     current comic =====> 2782

# %% [markdown]
# ## The `get_comic()` function
# Parameters
#   - verbose : `bool`
#     - by default verbose is set to false. The output is same as the output as the cell above as it uses the `get_latest_comic()` function
#   - comic : `str`
#     - use string `"latest"` for the latest comic
#     - use `"< some integer >"` for getting a specific comic
# ```
# # Example Code
# xkcd.get_comic(comic="199")
# ```

# %% [markdown]
# ## Comic class functions
#
# 1. To display the latest comic
# ```python
# # Example Code
# comic.display()
# ```
#
# 2. To display the
# ```python
# # Example Code
# comic.show()
# ```

# %%
comic.display()
# Out:
# XKCD Comic 199
#     > year 2006
#     > title Right-Hand Rule
#     > comic https://imgs.xkcd.com/comics/right_hand_rule.png
#     > alt To really expand your mind try some noncartesian porn.  Edwin Abbot Abbott has nothing on 'Girls on Girls in Tightly Closed Nonorientable Spaces'.

# %%
comic.show()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=550x739 at 0x7F1029FE7C10>
